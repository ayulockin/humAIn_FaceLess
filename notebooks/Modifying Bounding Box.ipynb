# %%
import matplotlib.pyplot as plt

# %matplotlib inline

import cv2
import os
import json
import argparse

# %%
from face_detector.facedetection import faceDetection
# from face_detector.identifyface import IdentifyFace

# %%
face_detector = faceDetection()
# Out:
# WARNING:tensorflow:From C:\Users\Ayush\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From E:\humAIn\humAIn_faceless\humAIn_FaceLess\face_detector\architecture\layer_factory.py:197: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %%
image = cv2.imread('examples/example1.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image.shape
plt.imshow(image)

# %%
result = face_detector.detect_faces(image)
print(result)
# Out:
# [{'box': [57, 26, 49, 59], 'confidence': 0.9999687671661377}, {'box': [115, 115, 39, 58], 'confidence': 0.9988548755645752}]

# %%
image = face_detector.drawBoundingBox(image, result)
plt.imshow(image)

# %%
cv2.rectangle(image, (57, 26), 
             (57+49, 26+59),
             (0,155,255), 2)
# Out:
# (284, 316, 3)

# %%
plt.imshow(image)

# %%
cv2.circle(image,(57,26),10,(0,255,255), 2)
# Out:
# array([[[126, 109,  65],
#         [130, 112,  66],
#         [131, 110,  65],
#         ...,
#         [156,  81,  60],
#         [161,  96,  76],
#         [164, 111,  93]],
#
#        [[125, 107,  61],
#         [127, 109,  63],
#         [128, 110,  62],
#         ...,
#         [157,  90,  73],
#         [167, 115,  94],
#         [173, 136, 107]],
#
#        [[124, 107,  63],
#         [123, 108,  65],
#         [121, 109,  61],
#         ...,
#         [165, 115,  92],
#         [173, 141, 103],
#         [185, 164, 101]],
#
#        ...,
#
#        [[152, 126,  75],
#         [151, 125,  74],
#         [152, 124,  74],
#         ...,
#         [  0,  85, 168],
#         [  2,  84, 168],
#         [  0,  82, 164]],
#
#        [[151, 125,  74],
#         [151, 125,  74],
#         [151, 126,  72],
#         ...,
#         [  0,  86, 169],
#         [  1,  86, 169],
#         [  1,  83, 165]],
#
#        [[154, 126,  76],
#         [151, 125,  76],
#         [151, 126,  72],
#         ...,
#         [  0,  86, 169],
#         [  1,  86, 169],
#         [  1,  83, 165]]], dtype=uint8)

# %%
plt.imshow(image)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)

# %%
plt.imshow(image)

# %%
for (x,y,w,h) in faces:
    print(x,y,w,h)
# Out:
# 108 116 59 59

# %%
cv2.rectangle(image, (115, 115), 
             (115+39, 115+58),
             (0,155,255), 2);

# %%
plt.imshow(image)

# %%
cv2.rectangle(image, (115-10, 115-10), 
             (115-10+39+10, 115-10+58+10),
             (155,155,255), 2);

# %%
plt.imshow(image)
